# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
one = [0.33947772657450076, 0.42857142857142855, 0.36363636363636365, 0.23809523809523808, 0.4090909090909091, 0.36363636363636365, 0.5454545454545454, 0.6818181818181818, 0.5909090909090909, 0.8571428571428571, 0.9090909090909091, 0.9523809523809523, 0.9545454545454546, 1.0, 0.9545454545454546, 0.9720930232558139]
two = [0.10891089108910891, 0.07920792079207921, 0.15841584158415842, 0.18, 0.10679611650485436, 0.10891089108910891, 0.1188118811881188, 0.17475728155339806, 0.8252427184466019, 0.9215686274509803, 0.912621359223301, 0.9029126213592233, 0.8431372549019608, 0.8921568627450981, 0.8333333333333334, 0.900990099009901]
three = [0.24479166666666666, 0.21875, 0.34375, 0.21875, 0.3125, 0.28125, 0.3125, 0.34375, 0.4375, 0.6875, 0.84375, 1.0, 0.9375, 1.0, 1.0, 0.9982638888888888]
four = [0.06800618238021638, 0.045454545454545456, 0.22727272727272727, 0.045454545454545456, 0.13636363636363635, 0.045454545454545456, 0.22727272727272727, 0.14285714285714285, 0.13636363636363635, 0.22727272727272727, 0.4090909090909091, 0.5909090909090909, 0.7272727272727273, 0.5238095238095238, 0.9523809523809523, 0.9521604938271605]

plt.figure(figsize=(11, 10))
all_psycho = np.array([one, two, three, four])
plt.ylim((0, 1))
plt.plot(np.linspace(15, 65, 16), one, color='grey')
plt.plot(np.linspace(15, 65, 16), two, color='grey')
plt.plot(np.linspace(15, 65, 16), three, color='grey')
plt.plot(np.linspace(15, 65, 16), four, color='grey')
plt.ylabel('Prob. of lick')
plt.xlabel('Harm. 2 dB')
plt.plot(np.linspace(15, 65, 16), np.mean(all_psycho, axis=0), 'o-', color='goldenrod')
plt.savefig('all_psycho07062022_tmp.svg')

# %%
print(np.linspace(15, 65, 16))
# Out:
# [15.         18.33333333 21.66666667 25.         28.33333333 31.66666667
#  35.         38.33333333 41.66666667 45.         48.33333333 51.66666667
#  55.         58.33333333 61.66666667 65.        ]
